# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('data.csv')
data.columns = ['X','Y']
data.sample(5)
# Out:
#             X          Y
# 12  58.168471  75.392870
# 90  53.691640  85.668203
# 85  51.088720  69.588898
# 59  41.182016  61.684038
# 18  38.816818  56.877213

# %%
from sklearn import model_selection
x = data[['X']]
y = data['Y']
print(x.shape, y.shape)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y)
# Out:
# (99, 1) (99,)

# %%
from sklearn.linear_model import LinearRegression
algorithm = LinearRegression()
algorithm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
algorithm.coef_
# Out:
# array([1.31070925])

# %%
algorithm.intercept_
# Out:
# 8.846602633399925

# %%
import numpy as np
plt.scatter(data['X'], data['Y'])
plt.plot(x_train,algorithm.predict(x_train))
plt.show()

# %%
y_predict = algorithm.predict(x_test)
plt.scatter(data['X'], data['Y'])
plt.plot(x_test, y_predict)
plt.show()
